# %% [markdown]
# ## Generates a dataset of aggregated data based on groupId

# %%
import pandas as pd

df = pd.read_csv('train_V2.csv')
df.head()
# Out:
#                Id         groupId         matchId  assists  boosts  \
# 0  7f96b2f878858a  4d4b580de459be  a10357fd1a4a91        0       0
# 1  eef90569b9d03c  684d5656442f9e  aeb375fc57110c        0       0
# 2  1eaf90ac73de72  6a4a42c3245a74  110163d8bb94ae        1       0
# 3  4616d365dd2853  a930a9c79cd721  f1f1f4ef412d7e        0       0
# 4  315c96c26c9aac  de04010b3458dd  6dc8ff871e21e6        0       0
#
#    damageDealt  DBNOs  headshotKills  heals  killPlace  ...  revives  \
# 0         0.00      0              0      0         60  ...        0
# 1        91.47      0              0      0         57  ...        0
# 2        68.00      0              0      0         47  ...        0
# 3        32.90      0              0      0         75  ...        0
# 4       100.00      0              0      0         45  ...        0
#
#    rideDistance  roadKills  swimDistance  teamKills vehicleDestroys  \
# 0        0.0000          0          0.00          0               0
# 1        0.0045          0         11.04          0               0
# 2        0.0000          0          0.00          0               0
# 3        0.0000          0          0.00          0               0
# 4        0.0000          0          0.00          0               0
#
#    walkDistance  weaponsAcquired  winPoints  winPlacePerc
# 0        244.80                1       1466        0.4444
# 1       1434.00                5          0        0.6400
# 2        161.80                2          0        0.7755
# 3        202.70                3          0        0.1667
# 4         49.75                2          0        0.1875
#
# [5 rows x 29 columns]

# %%
df.columns
# Out:
# Index(['Id', 'groupId', 'matchId', 'assists', 'boosts', 'damageDealt', 'DBNOs',
#        'headshotKills', 'heals', 'killPlace', 'killPoints', 'kills',
#        'killStreaks', 'longestKill', 'matchDuration', 'matchType', 'maxPlace',
#        'numGroups', 'rankPoints', 'revives', 'rideDistance', 'roadKills',
#        'swimDistance', 'teamKills', 'vehicleDestroys', 'walkDistance',
#        'weaponsAcquired', 'winPoints', 'winPlacePerc'],
#       dtype='object')

# %%
print(df.shape)
df.dropna(inplace=True)
print(df.shape)
# Out:
# (4446966, 29)
# (4446965, 29)

# %%
df.columns
# Out:
# Index(['Id', 'groupId', 'matchId', 'assists', 'boosts', 'damageDealt', 'DBNOs',
#        'headshotKills', 'heals', 'killPlace', 'killPoints', 'kills',
#        'killStreaks', 'longestKill', 'matchDuration', 'matchType', 'maxPlace',
#        'numGroups', 'rankPoints', 'revives', 'rideDistance', 'roadKills',
#        'swimDistance', 'teamKills', 'vehicleDestroys', 'walkDistance',
#        'weaponsAcquired', 'winPoints', 'winPlacePerc'],
#       dtype='object')

# %% [markdown]
# ### Defines how to aggregate the data for each group and creates the dataset

# %%
sum_col = ["assists","boosts","damageDealt","DBNOs","headshotKills","heals","kills","revives","rideDistance","roadKills","swimDistance","teamKills","vehicleDestroys","walkDistance","weaponsAcquired"]
avg_col = ["killPlace","killPoints","killStreaks","longestKill","rankPoints","winPoints"]
fixed_col = ["matchId","matchDuration","matchType","maxPlace","numGroups","winPlacePerc"]

agg_funcs = {col: "sum" for col  in sum_col}
agg_funcs.update({col: "mean" for col in avg_col})
agg_funcs.update({col: "first" for col in fixed_col})
df.drop
grouped_df = df.groupby("groupId").agg(agg_funcs)

grouped_df.head()
# Out:
#                 assists  boosts  damageDealt  DBNOs  headshotKills  heals  \
# groupId
# 00000c08b5be36        0       1       741.50      5              1      1
# 00000d1cbbc340        0       0       173.70      0              0      0
# 000025a09dd1d7        0       0         0.00      0              0      0
# 000038ec4dff53        2       7       790.67      5              1      9
# 00003a54230763        1       0       100.00      1              1      0
#
#                 kills  revives  rideDistance  roadKills  ...  killStreaks  \
# groupId                                                  ...
# 00000c08b5be36      2        0           0.0          0  ...     0.666667
# 00000d1cbbc340      1        0           0.0          0  ...     1.000000
# 000025a09dd1d7      0        0           0.0          0  ...     0.000000
# 000038ec4dff53      6        2           0.0          0  ...     1.000000
# 00003a54230763      1        0           0.0          0  ...     0.500000
#
#                 longestKill   rankPoints  winPoints         matchId  \
# groupId
# 00000c08b5be36     9.051667  1457.333333        0.0  660d439a723670
# 00000d1cbbc340     1.964000  1551.000000        0.0  370b420efc87f4
# 000025a09dd1d7     0.000000  1584.000000        0.0  7c86ac34f9ea9c
# 000038ec4dff53    53.510000  1516.000000        0.0  77a20700ee0c75
# 00003a54230763     1.585500    -1.000000     1501.0  5ff11bb177a286
#
#                 matchDuration  matchType  maxPlace  numGroups  winPlacePerc
# groupId
# 00000c08b5be36           1429      squad        26         26        0.2000
# 00000d1cbbc340           1196      squad        27         24        0.1154
# 000025a09dd1d7           2021   solo-fpp        91         89        0.2000
# 000038ec4dff53           1470      squad        27         27        0.9615
# 00003a54230763           2190    duo-fpp        44         42        0.1395
#
# [5 rows x 27 columns]

# %%
grouped_df.shape
# Out:
# (2026744, 27)

# %% [markdown]
# ### Same process for the test set

# %% [markdown]
# #### Checks whether there are groups that are splitted between the training and test set

# %%
testDF = pd.read_csv('test_V2.csv')

common_group_ids = set(df["groupId"]) & set(testDF["groupId"])

if common_group_ids:
    print(f"Common group ids found {common_group_ids}")
else:
    print("No common group ids found")
# Out:
# No common group ids found

# %%
fixed_col = ["matchId","matchDuration","matchType","maxPlace","numGroups"]
agg_funcs = {col: "sum" for col  in sum_col}
agg_funcs.update({col: "mean" for col in avg_col})
agg_funcs.update({col: "first" for col in fixed_col})
testDF.dropna(inplace=True)
#testDF.drop(columns=["Id"], inplace=True)
grouped_df_test = testDF.groupby("groupId").agg(agg_funcs)
grouped_df_test.head()
# Out:
#                 assists  boosts  damageDealt  DBNOs  headshotKills  heals  \
# groupId
# 00000b5b45f70c        1      19       300.56      3              0     20
# 00000fb8f2208b        1       0        94.60      0              0      0
# 0000120038fb95        1       3       223.50      0              0      3
# 00001e221235dd        0       2       831.90      4              2      8
# 000022937e1c55        0       4       323.00      3              0      6
#
#                 kills  revives  rideDistance  roadKills  ...  killPoints  \
# groupId                                                  ...
# 00000b5b45f70c      3        2       17266.0          1  ...         0.0
# 00000fb8f2208b      0        0           0.0          0  ...         0.0
# 0000120038fb95      2        1        1344.0          0  ...      1262.0
# 00001e221235dd      4        1           0.0          0  ...      1347.5
# 000022937e1c55      1        1           0.0          0  ...         0.0
#
#                 killStreaks  longestKill   rankPoints  winPoints  \
# groupId
# 00000b5b45f70c     0.333333    22.116667  1495.333333        0.0
# 00000fb8f2208b     0.000000     0.000000  1419.500000        0.0
# 0000120038fb95     0.500000    31.070000    -1.000000     1501.0
# 00001e221235dd     1.000000    17.780000    -1.000000     1488.0
# 000022937e1c55     0.250000     4.830000  1486.000000        0.0
#
#                        matchId  matchDuration  matchType  maxPlace  numGroups
# groupId
# 00000b5b45f70c  d58a74c8197fdf           1586      squad        26         25
# 00000fb8f2208b  acadebc66753a6           1359  squad-fpp        30         29
# 0000120038fb95  29fc53a093a0ab           1884    duo-fpp        48         45
# 00001e221235dd  d6867077cbb3c6           1337    duo-fpp        50         47
# 000022937e1c55  f8821ae0e3d262           1420      squad        26         26
#
# [5 rows x 26 columns]

# %% [markdown]
# ### Save both datasets

# %%
grouped_df.to_csv("train_grouped.csv")
grouped_df_test.to_csv("test_grouped.csv")
