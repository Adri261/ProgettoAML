# %%
import tensorflow as tf
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from matplotlib import pyplot as plt
import pandas as pd

csv_path = "./preprocessed_groupedDataset"
x_train = pd.read_csv("{}/X_train_grouped.csv".format(csv_path)).drop("matchId", axis=1)
x_val = pd.read_csv("{}/X_val_grouped.csv".format(csv_path)).drop("matchId", axis=1)
x_test = pd.read_csv("{}/X_test_grouped.csv".format(csv_path)).drop("matchId", axis=1)

y_train = pd.read_csv("{}/y_train_grouped.csv".format(csv_path))
y_val = pd.read_csv("{}/y_val_grouped.csv".format(csv_path))
y_test = pd.read_csv("{}/y_test_grouped.csv".format(csv_path))

x_train.head()
# Out:
#     assists    boosts  damageDealt     DBNOs  headshotKills     heals  \
# 0 -0.424084  0.157354    -0.202407 -0.610182      -0.487562 -0.183165
# 1  6.189015  0.432793     2.309263  2.348845       3.431162  0.180872
# 2 -0.424084  1.259108     0.475750 -0.187464      -0.487562  0.544910
# 3  7.015652  4.013491     2.996809  2.348845       3.431162  3.093172
# 4 -0.424084 -0.668961    -0.811108 -0.610182      -0.487562 -0.547203
#
#       kills   revives  rideDistance  roadKills  ...  matchType_normal-duo  \
# 0 -0.668142 -0.425820      3.050989  -0.067939  ...                     0
# 1  2.953926 -0.425820     -0.375138  -0.067939  ...                     0
# 2 -0.338863  0.752806     -0.006151  -0.067939  ...                     0
# 3  3.941763 -0.425820      1.823947  -0.067939  ...                     0
# 4 -0.668142 -0.425820     -0.375138  -0.067939  ...                     0
#
#    matchType_normal-duo-fpp  matchType_normal-solo  matchType_normal-solo-fpp  \
# 0                         0                      0                          0
# 1                         0                      0                          0
# 2                         0                      0                          0
# 3                         0                      0                          0
# 4                         0                      0                          0
#
#    matchType_normal-squad  matchType_normal-squad-fpp  matchType_solo  \
# 0                       0                           0               0
# 1                       0                           0               0
# 2                       0                           0               0
# 3                       0                           0               0
# 4                       0                           0               1
#
#    matchType_solo-fpp  matchType_squad  matchType_squad-fpp
# 0                   0                1                    0
# 1                   0                0                    1
# 2                   0                1                    0
# 3                   0                1                    0
# 4                   0                0                    0
#
# [5 rows x 40 columns]

# %%
scaler = StandardScaler()
scaled_data = scaler.fit_transform(x_train)
pca = PCA().fit(scaled_data)

plt.plot(range(1, pca.n_components_ + 1), pca.explained_variance_ratio_, marker='o')
plt.xlabel('Componenti della PCA')
plt.ylabel('Varianza spiegata')
plt.title("Risultati della PCA")
plt.show()

# %%
components = 25
pca = PCA(n_components=components).fit(scaled_data)
X_train_pca = pca.transform(scaled_data)
print("Final input shape train: {}".format(X_train_pca.shape))

scaled_data = scaler.fit_transform(x_val)
x_val_pca = pca.transform(scaled_data)
print("Final input shape val: {}".format(x_val_pca.shape))

scaled_data = scaler.fit_transform(x_test)
x_test_pca = pca.transform(scaled_data)
print("Final input shape test: {}".format(x_test_pca.shape))
# Out:
# Final input shape train: (1297116, 25)
# Final input shape val: (324279, 25)
# Final input shape test: (405349, 25)

# %% [markdown]
# # Baseline Model

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation,Input
from keras.optimizers import Adam

learning_rate = 0.001
n_epochs = 50
batch_size = 1024

model = Sequential()
model.add(Input(shape=(x_train.shape[1],)))
model.add(Dense(128,activation='relu'))
model.add(Dense(64,activation='relu'))
model.add(Dense(1,activation='relu'))

optimizer = Adam(learning_rate=learning_rate)
model.compile(optimizer=optimizer,loss='mean_squared_error',metrics=['mean_absolute_error'])
history = model.fit(x_train,y_train,validation_data=(x_val,y_val),epochs=n_epochs,batch_size=batch_size)

def plot_loss(history, model_name):
  x_plot = list(range(1,len(history.history["loss"])+1))
  plt.figure()
  plt.title("Loss")
  plt.xlabel('Epochs')
  plt.ylabel('Loss')
  plt.plot(x_plot, history.history['loss'])
  plt.plot(x_plot, history.history['val_loss'])
  plt.legend(['Training', 'Validation'])
  plt.savefig("./models_plots/loss_{}.png".format(model_name))

def plot_mae(history, model_name):
  x_plot = list(range(1,len(history.history["mean_absolute_error"])+1))
  plt.figure()
  plt.title("Mean Absolute Error")
  plt.xlabel('Epochs')
  plt.ylabel('Mean Absolute Error')
  plt.plot(x_plot, history.history['mean_absolute_error'])
  plt.plot(x_plot, history.history['val_mean_absolute_error'])
  plt.legend(['Training', 'Validation'])
  plt.savefig("./models_plots/mae_{}.png".format(model_name))

model_dir = "./saved_models"

model_name = "baseline_model_{}e_{}bsize_adam_lr{}".format(n_epochs, batch_size, learning_rate)


plot_loss(history, model_name)
plot_mae(history, model_name)


model.save('{}/{}.h5'.format(model_dir,model_name))
# Out:
# Epoch 1/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0204 - mean_absolute_error: 0.0890 - val_loss: 0.0060 - val_mean_absolute_error: 0.0573
# Epoch 2/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0058 - mean_absolute_error: 0.0557 - val_loss: 0.0055 - val_mean_absolute_error: 0.0545
# Epoch 3/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0054 - mean_absolute_error: 0.0538 - val_loss: 0.0053 - val_mean_absolute_error: 0.0531
# Epoch 4/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0052 - mean_absolute_error: 0.0527 - val_loss: 0.0051 - val_mean_absolute_error: 0.0522
# Epoch 5/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0051 - mean_absolute_error: 0.0521 - val_loss: 0.0050 - val_mean_absolute_error: 0.0514
# Epoch 6/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0050 - mean_absolute_error: 0.0516 - val_loss: 0.0051 - val_mean_absolute_error: 0.0517
# Epoch 7/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0049 - mean_absolute_error: 0.0512 - val_loss: 0.0048 - val_mean_absolute_error: 0.0503
# Epoch 8/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0048 - mean_absolute_error: 0.0507 - val_loss: 0.0050 - val_mean_absolute_error: 0.0516
# Epoch 9/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0048 - mean_absolute_error: 0.0505 - val_loss: 0.0048 - val_mean_absolute_error: 0.0505
# Epoch 10/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0047 - mean_absolute_error: 0.0502 - val_loss: 0.0047 - val_mean_absolute_error: 0.0499
# Epoch 11/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0047 - mean_absolute_error: 0.0499 - val_loss: 0.0048 - val_mean_absolute_error: 0.0503
# Epoch 12/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0046 - mean_absolute_error: 0.0498 - val_loss: 0.0046 - val_mean_absolute_error: 0.0495
# Epoch 13/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0046 - mean_absolute_error: 0.0497 - val_loss: 0.0046 - val_mean_absolute_error: 0.0494
# Epoch 14/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0046 - mean_absolute_error: 0.0496 - val_loss: 0.0046 - val_mean_absolute_error: 0.0496
# Epoch 15/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0046 - mean_absolute_error: 0.0495 - val_loss: 0.0046 - val_mean_absolute_error: 0.0492
# Epoch 16/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0046 - mean_absolute_error: 0.0494 - val_loss: 0.0046 - val_mean_absolute_error: 0.0492
# Epoch 17/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0046 - mean_absolute_error: 0.0493 - val_loss: 0.0047 - val_mean_absolute_error: 0.0497
# Epoch 18/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0046 - mean_absolute_error: 0.0493 - val_loss: 0.0046 - val_mean_absolute_error: 0.0500
# Epoch 19/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0045 - mean_absolute_error: 0.0492 - val_loss: 0.0046 - val_mean_absolute_error: 0.0496
# Epoch 20/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0045 - mean_absolute_error: 0.0490 - val_loss: 0.0046 - val_mean_absolute_error: 0.0493
# Epoch 21/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0045 - mean_absolute_error: 0.0491 - val_loss: 0.0045 - val_mean_absolute_error: 0.0488
# Epoch 22/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0045 - mean_absolute_error: 0.0490 - val_loss: 0.0046 - val_mean_absolute_error: 0.0490
# Epoch 23/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0045 - mean_absolute_error: 0.0490 - val_loss: 0.0045 - val_mean_absolute_error: 0.0490
# Epoch 24/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0045 - mean_absolute_error: 0.0489 - val_loss: 0.0045 - val_mean_absolute_error: 0.0491
# Epoch 25/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0045 - mean_absolute_error: 0.0488 - val_loss: 0.0045 - val_mean_absolute_error: 0.0492
# Epoch 26/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0045 - mean_absolute_error: 0.0488 - val_loss: 0.0045 - val_mean_absolute_error: 0.0487
# Epoch 27/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0045 - mean_absolute_error: 0.0488 - val_loss: 0.0045 - val_mean_absolute_error: 0.0486
# Epoch 28/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0045 - mean_absolute_error: 0.0487 - val_loss: 0.0045 - val_mean_absolute_error: 0.0489
# Epoch 29/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0044 - mean_absolute_error: 0.0487 - val_loss: 0.0045 - val_mean_absolute_error: 0.0486
# Epoch 30/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0044 - mean_absolute_error: 0.0486 - val_loss: 0.0045 - val_mean_absolute_error: 0.0489
# Epoch 31/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0044 - mean_absolute_error: 0.0486 - val_loss: 0.0046 - val_mean_absolute_error: 0.0493
# Epoch 32/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0044 - mean_absolute_error: 0.0487 - val_loss: 0.0045 - val_mean_absolute_error: 0.0487
# Epoch 33/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0044 - mean_absolute_error: 0.0486 - val_loss: 0.0045 - val_mean_absolute_error: 0.0488
# Epoch 34/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0044 - mean_absolute_error: 0.0485 - val_loss: 0.0045 - val_mean_absolute_error: 0.0486
# Epoch 35/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0044 - mean_absolute_error: 0.0485 - val_loss: 0.0045 - val_mean_absolute_error: 0.0485
# Epoch 36/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0044 - mean_absolute_error: 0.0484 - val_loss: 0.0045 - val_mean_absolute_error: 0.0490
# Epoch 37/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0044 - mean_absolute_error: 0.0484 - val_loss: 0.0044 - val_mean_absolute_error: 0.0485
# Epoch 38/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0044 - mean_absolute_error: 0.0485 - val_loss: 0.0045 - val_mean_absolute_error: 0.0489
# Epoch 39/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0044 - mean_absolute_error: 0.0484 - val_loss: 0.0045 - val_mean_absolute_error: 0.0485
# Epoch 40/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0044 - mean_absolute_error: 0.0484 - val_loss: 0.0044 - val_mean_absolute_error: 0.0485
# Epoch 41/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0044 - mean_absolute_error: 0.0484 - val_loss: 0.0044 - val_mean_absolute_error: 0.0483
# Epoch 42/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0044 - mean_absolute_error: 0.0484 - val_loss: 0.0044 - val_mean_absolute_error: 0.0485
# Epoch 43/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0044 - mean_absolute_error: 0.0484 - val_loss: 0.0044 - val_mean_absolute_error: 0.0486
# Epoch 44/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0044 - mean_absolute_error: 0.0484 - val_loss: 0.0045 - val_mean_absolute_error: 0.0484
# Epoch 45/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0044 - mean_absolute_error: 0.0483 - val_loss: 0.0044 - val_mean_absolute_error: 0.0484
# Epoch 46/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0044 - mean_absolute_error: 0.0484 - val_loss: 0.0045 - val_mean_absolute_error: 0.0487
# Epoch 47/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0044 - mean_absolute_error: 0.0483 - val_loss: 0.0044 - val_mean_absolute_error: 0.0483
# Epoch 48/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0044 - mean_absolute_error: 0.0482 - val_loss: 0.0044 - val_mean_absolute_error: 0.0484
# Epoch 49/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0044 - mean_absolute_error: 0.0483 - val_loss: 0.0045 - val_mean_absolute_error: 0.0488
# Epoch 50/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0044 - mean_absolute_error: 0.0483 - val_loss: 0.0044 - val_mean_absolute_error: 0.0483
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# # PCA model

# %%
learning_rate = 0.001
n_epochs = 50
batch_size = 1024

model = Sequential()
model.add(Input(shape=(X_train_pca.shape[1],)))
model.add(Dense(128,activation='relu'))
model.add(Dense(64,activation='relu'))
model.add(Dense(1,activation='relu'))

optimizer = Adam(learning_rate=learning_rate)
model.compile(optimizer=optimizer,loss='mean_squared_error',metrics=['mean_absolute_error'])
history = model.fit(X_train_pca,y_train,validation_data=(x_val_pca,y_val),epochs=n_epochs,batch_size=batch_size)

model_name = "pca_baseline_model_{}e_{}bsize_adam_lr{}".format(n_epochs, batch_size, learning_rate)
model_names.append(model_name)

plot_loss(history, model_name)
plot_mae(history, model_name)

model.save('{}/{}.h5'.format(model_dir,model_name))
# Out:
# Epoch 1/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0307 - mean_absolute_error: 0.1111 - val_loss: 0.0104 - val_mean_absolute_error: 0.0744
# Epoch 2/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0104 - mean_absolute_error: 0.0740 - val_loss: 0.0098 - val_mean_absolute_error: 0.0715
# Epoch 3/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0097 - mean_absolute_error: 0.0710 - val_loss: 0.0092 - val_mean_absolute_error: 0.0686
# Epoch 4/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0092 - mean_absolute_error: 0.0691 - val_loss: 0.0090 - val_mean_absolute_error: 0.0676
# Epoch 5/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0090 - mean_absolute_error: 0.0678 - val_loss: 0.0085 - val_mean_absolute_error: 0.0661
# Epoch 6/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0085 - mean_absolute_error: 0.0662 - val_loss: 0.0083 - val_mean_absolute_error: 0.0660
# Epoch 7/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0083 - mean_absolute_error: 0.0650 - val_loss: 0.0081 - val_mean_absolute_error: 0.0652
# Epoch 8/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0081 - mean_absolute_error: 0.0643 - val_loss: 0.0079 - val_mean_absolute_error: 0.0637
# Epoch 9/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0079 - mean_absolute_error: 0.0632 - val_loss: 0.0078 - val_mean_absolute_error: 0.0635
# Epoch 10/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0077 - mean_absolute_error: 0.0625 - val_loss: 0.0075 - val_mean_absolute_error: 0.0611
# Epoch 11/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0076 - mean_absolute_error: 0.0620 - val_loss: 0.0074 - val_mean_absolute_error: 0.0610
# Epoch 12/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0074 - mean_absolute_error: 0.0613 - val_loss: 0.0074 - val_mean_absolute_error: 0.0618
# Epoch 13/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0073 - mean_absolute_error: 0.0607 - val_loss: 0.0071 - val_mean_absolute_error: 0.0599
# Epoch 14/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0073 - mean_absolute_error: 0.0605 - val_loss: 0.0071 - val_mean_absolute_error: 0.0601
# Epoch 15/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0071 - mean_absolute_error: 0.0601 - val_loss: 0.0071 - val_mean_absolute_error: 0.0597
# Epoch 16/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0070 - mean_absolute_error: 0.0597 - val_loss: 0.0072 - val_mean_absolute_error: 0.0603
# Epoch 17/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0070 - mean_absolute_error: 0.0593 - val_loss: 0.0069 - val_mean_absolute_error: 0.0587
# Epoch 18/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0082 - mean_absolute_error: 0.0594 - val_loss: 0.0070 - val_mean_absolute_error: 0.0594
# Epoch 19/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0070 - mean_absolute_error: 0.0592 - val_loss: 0.0068 - val_mean_absolute_error: 0.0580
# Epoch 20/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0068 - mean_absolute_error: 0.0587 - val_loss: 0.0067 - val_mean_absolute_error: 0.0580
# Epoch 21/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0068 - mean_absolute_error: 0.0585 - val_loss: 0.0067 - val_mean_absolute_error: 0.0581
# Epoch 22/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0068 - mean_absolute_error: 0.0583 - val_loss: 0.0067 - val_mean_absolute_error: 0.0579
# Epoch 23/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0067 - mean_absolute_error: 0.0579 - val_loss: 0.0066 - val_mean_absolute_error: 0.0577
# Epoch 24/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0067 - mean_absolute_error: 0.0579 - val_loss: 0.0104 - val_mean_absolute_error: 0.0584
# Epoch 25/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0067 - mean_absolute_error: 0.0580 - val_loss: 0.0066 - val_mean_absolute_error: 0.0578
# Epoch 26/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0066 - mean_absolute_error: 0.0576 - val_loss: 0.0066 - val_mean_absolute_error: 0.0575
# Epoch 27/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0066 - mean_absolute_error: 0.0576 - val_loss: 0.0065 - val_mean_absolute_error: 0.0576
# Epoch 28/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0066 - mean_absolute_error: 0.0573 - val_loss: 0.0066 - val_mean_absolute_error: 0.0574
# Epoch 29/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0066 - mean_absolute_error: 0.0572 - val_loss: 0.0065 - val_mean_absolute_error: 0.0575
# Epoch 30/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0065 - mean_absolute_error: 0.0569 - val_loss: 0.0064 - val_mean_absolute_error: 0.0567
# Epoch 31/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0070 - mean_absolute_error: 0.0574 - val_loss: 0.0064 - val_mean_absolute_error: 0.0567
# Epoch 32/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0064 - mean_absolute_error: 0.0568 - val_loss: 0.0064 - val_mean_absolute_error: 0.0570
# Epoch 33/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0065 - mean_absolute_error: 0.0568 - val_loss: 0.0064 - val_mean_absolute_error: 0.0568
# Epoch 34/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0065 - mean_absolute_error: 0.0568 - val_loss: 0.0063 - val_mean_absolute_error: 0.0561
# Epoch 35/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0064 - mean_absolute_error: 0.0566 - val_loss: 0.0064 - val_mean_absolute_error: 0.0563
# Epoch 36/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0065 - mean_absolute_error: 0.0568 - val_loss: 0.0064 - val_mean_absolute_error: 0.0567
# Epoch 37/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0064 - mean_absolute_error: 0.0564 - val_loss: 0.0065 - val_mean_absolute_error: 0.0565
# Epoch 38/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0064 - mean_absolute_error: 0.0563 - val_loss: 0.0062 - val_mean_absolute_error: 0.0559
# Epoch 39/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0064 - mean_absolute_error: 0.0564 - val_loss: 0.0063 - val_mean_absolute_error: 0.0559
# Epoch 40/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 0.0063 - mean_absolute_error: 0.0561 - val_loss: 0.0063 - val_mean_absolute_error: 0.0564
# Epoch 41/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0063 - mean_absolute_error: 0.0560 - val_loss: 0.0062 - val_mean_absolute_error: 0.0555
# Epoch 42/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0063 - mean_absolute_error: 0.0559 - val_loss: 0.0063 - val_mean_absolute_error: 0.0561
# Epoch 43/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0063 - mean_absolute_error: 0.0560 - val_loss: 0.0062 - val_mean_absolute_error: 0.0556
# Epoch 44/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0063 - mean_absolute_error: 0.0558 - val_loss: 0.0063 - val_mean_absolute_error: 0.0555
# Epoch 45/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0062 - mean_absolute_error: 0.0556 - val_loss: 0.0064 - val_mean_absolute_error: 0.0568
# Epoch 46/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0062 - mean_absolute_error: 0.0556 - val_loss: 0.0062 - val_mean_absolute_error: 0.0559
# Epoch 47/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0062 - mean_absolute_error: 0.0556 - val_loss: 0.0061 - val_mean_absolute_error: 0.0555
# Epoch 48/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0062 - mean_absolute_error: 0.0554 - val_loss: 0.0060 - val_mean_absolute_error: 0.0548
# Epoch 49/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0061 - mean_absolute_error: 0.0553 - val_loss: 0.0063 - val_mean_absolute_error: 0.0558
# Epoch 50/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0061 - mean_absolute_error: 0.0553 - val_loss: 0.0060 - val_mean_absolute_error: 0.0550
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
learning_rate = 0.001
n_epochs = 50
batch_size = 1024
model = Sequential()
model.add(Input(shape=(X_train_pca.shape[1],)))
model.add(Dense(64,activation='relu'))
model.add(Dense(32,activation='relu'))
model.add(Dense(1,activation='relu'))

optimizer = Adam(learning_rate=learning_rate)
model.compile(optimizer=optimizer,loss='mean_squared_error',metrics=['mean_absolute_error'])
history = model.fit(X_train_pca,y_train,validation_data=(x_val_pca,y_val),epochs=n_epochs,batch_size=batch_size)

model_name = "pca_baseline_model_reduced_{}e_{}bsize_adam_lr{}".format(n_epochs, batch_size, learning_rate)


plot_loss(history, model_name)
plot_mae(history, model_name)

model.save('{}/{}.h5'.format(model_dir,model_name))
# Out:
# Epoch 1/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0318 - mean_absolute_error: 0.1169 - val_loss: 0.0117 - val_mean_absolute_error: 0.0783
# Epoch 2/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0112 - mean_absolute_error: 0.0768 - val_loss: 0.0103 - val_mean_absolute_error: 0.0734
# Epoch 3/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0103 - mean_absolute_error: 0.0733 - val_loss: 0.0099 - val_mean_absolute_error: 0.0717
# Epoch 4/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0098 - mean_absolute_error: 0.0716 - val_loss: 0.0097 - val_mean_absolute_error: 0.0703
# Epoch 5/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0096 - mean_absolute_error: 0.0703 - val_loss: 0.0096 - val_mean_absolute_error: 0.0714
# Epoch 6/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0094 - mean_absolute_error: 0.0695 - val_loss: 0.0090 - val_mean_absolute_error: 0.0680
# Epoch 7/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0091 - mean_absolute_error: 0.0684 - val_loss: 0.0088 - val_mean_absolute_error: 0.0672
# Epoch 8/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0089 - mean_absolute_error: 0.0674 - val_loss: 0.0086 - val_mean_absolute_error: 0.0667
# Epoch 9/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0086 - mean_absolute_error: 0.0662 - val_loss: 0.0084 - val_mean_absolute_error: 0.0656
# Epoch 10/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0084 - mean_absolute_error: 0.0654 - val_loss: 0.0085 - val_mean_absolute_error: 0.0659
# Epoch 11/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0082 - mean_absolute_error: 0.0647 - val_loss: 0.0080 - val_mean_absolute_error: 0.0640
# Epoch 12/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0081 - mean_absolute_error: 0.0640 - val_loss: 0.0079 - val_mean_absolute_error: 0.0632
# Epoch 13/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0082 - mean_absolute_error: 0.0636 - val_loss: 0.0078 - val_mean_absolute_error: 0.0631
# Epoch 14/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0079 - mean_absolute_error: 0.0631 - val_loss: 0.0077 - val_mean_absolute_error: 0.0630
# Epoch 15/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0077 - mean_absolute_error: 0.0625 - val_loss: 0.0077 - val_mean_absolute_error: 0.0633
# Epoch 16/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0077 - mean_absolute_error: 0.0623 - val_loss: 0.0075 - val_mean_absolute_error: 0.0613
# Epoch 17/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0075 - mean_absolute_error: 0.0618 - val_loss: 0.0076 - val_mean_absolute_error: 0.0619
# Epoch 18/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0075 - mean_absolute_error: 0.0616 - val_loss: 0.0074 - val_mean_absolute_error: 0.0611
# Epoch 19/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0075 - mean_absolute_error: 0.0613 - val_loss: 0.0074 - val_mean_absolute_error: 0.0613
# Epoch 20/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0074 - mean_absolute_error: 0.0611 - val_loss: 0.0073 - val_mean_absolute_error: 0.0609
# Epoch 21/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0073 - mean_absolute_error: 0.0607 - val_loss: 0.0072 - val_mean_absolute_error: 0.0602
# Epoch 22/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0073 - mean_absolute_error: 0.0607 - val_loss: 0.0072 - val_mean_absolute_error: 0.0600
# Epoch 23/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0072 - mean_absolute_error: 0.0603 - val_loss: 0.0071 - val_mean_absolute_error: 0.0599
# Epoch 24/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0073 - mean_absolute_error: 0.0606 - val_loss: 0.0072 - val_mean_absolute_error: 0.0600
# Epoch 25/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0072 - mean_absolute_error: 0.0599 - val_loss: 0.0070 - val_mean_absolute_error: 0.0593
# Epoch 26/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0071 - mean_absolute_error: 0.0599 - val_loss: 0.0071 - val_mean_absolute_error: 0.0594
# Epoch 27/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0071 - mean_absolute_error: 0.0596 - val_loss: 0.0070 - val_mean_absolute_error: 0.0598
# Epoch 28/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0070 - mean_absolute_error: 0.0594 - val_loss: 0.0069 - val_mean_absolute_error: 0.0587
# Epoch 29/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0070 - mean_absolute_error: 0.0591 - val_loss: 0.0069 - val_mean_absolute_error: 0.0594
# Epoch 30/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0070 - mean_absolute_error: 0.0591 - val_loss: 0.0070 - val_mean_absolute_error: 0.0593
# Epoch 31/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0069 - mean_absolute_error: 0.0589 - val_loss: 0.0069 - val_mean_absolute_error: 0.0593
# Epoch 32/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0069 - mean_absolute_error: 0.0589 - val_loss: 0.0069 - val_mean_absolute_error: 0.0588
# Epoch 33/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0069 - mean_absolute_error: 0.0587 - val_loss: 0.0068 - val_mean_absolute_error: 0.0583
# Epoch 34/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0069 - mean_absolute_error: 0.0587 - val_loss: 0.0070 - val_mean_absolute_error: 0.0593
# Epoch 35/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0069 - mean_absolute_error: 0.0586 - val_loss: 0.0069 - val_mean_absolute_error: 0.0588
# Epoch 36/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0068 - mean_absolute_error: 0.0584 - val_loss: 0.0067 - val_mean_absolute_error: 0.0581
# Epoch 37/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0068 - mean_absolute_error: 0.0584 - val_loss: 0.0067 - val_mean_absolute_error: 0.0580
# Epoch 38/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0068 - mean_absolute_error: 0.0583 - val_loss: 0.0068 - val_mean_absolute_error: 0.0586
# Epoch 39/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0068 - mean_absolute_error: 0.0582 - val_loss: 0.0069 - val_mean_absolute_error: 0.0589
# Epoch 40/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0067 - mean_absolute_error: 0.0581 - val_loss: 0.0068 - val_mean_absolute_error: 0.0586
# Epoch 41/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0067 - mean_absolute_error: 0.0581 - val_loss: 0.0066 - val_mean_absolute_error: 0.0577
# Epoch 42/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0067 - mean_absolute_error: 0.0579 - val_loss: 0.0066 - val_mean_absolute_error: 0.0575
# Epoch 43/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0067 - mean_absolute_error: 0.0580 - val_loss: 0.0068 - val_mean_absolute_error: 0.0584
# Epoch 44/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0068 - mean_absolute_error: 0.0581 - val_loss: 0.0066 - val_mean_absolute_error: 0.0578
# Epoch 45/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0067 - mean_absolute_error: 0.0578 - val_loss: 0.0066 - val_mean_absolute_error: 0.0573
# Epoch 46/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0066 - mean_absolute_error: 0.0576 - val_loss: 0.0066 - val_mean_absolute_error: 0.0574
# Epoch 47/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0067 - mean_absolute_error: 0.0577 - val_loss: 0.0066 - val_mean_absolute_error: 0.0575
# Epoch 48/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0066 - mean_absolute_error: 0.0576 - val_loss: 0.0066 - val_mean_absolute_error: 0.0579
# Epoch 49/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0066 - mean_absolute_error: 0.0574 - val_loss: 0.0065 - val_mean_absolute_error: 0.0572
# Epoch 50/50
# 1267/1267 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0067 - mean_absolute_error: 0.0577 - val_loss: 0.0066 - val_mean_absolute_error: 0.0574
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from tensorflow.keras.models import load_model
import numpy as np
from sklearn.metrics import mean_absolute_error
import os
model_dir = "./saved_models"
model_names = os.listdir(path = model_dir)
for model_name in model_names:
    model_name = model_name.split(".h5")[0]
    model = load_model('{}/{}.h5'.format(model_dir, model_name))
    if("pca" in model_name):
        predictions = np.array(model(x_test_pca))
    else:
        predictions = np.array(model(x_test))
    mae = mean_absolute_error(y_test, predictions)
    print("Testing model: {}, saved at: {}".format(model_name, '{}/{}.h5'.format(model_dir, model_name)))
    print("MAE: {}".format(mae))
    print("--------------------------------------------------------")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Testing model: baseline_model_50e_1024bsize_adam_lr0.001, saved at: ./saved_models/baseline_model_50e_1024bsize_adam_lr0.001.h5
# MAE: 0.04840100556612015
# --------------------------------------------------------
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Testing model: pca_baseline_model_50e_1024bsize_adam_lr0.001, saved at: ./saved_models/pca_baseline_model_50e_1024bsize_adam_lr0.001.h5
# MAE: 0.055048465728759766
# --------------------------------------------------------
# Testing model: pca_baseline_model_reduced_50e_1024bsize_adam_lr0.001, saved at: ./saved_models/pca_baseline_model_reduced_50e_1024bsize_adam_lr0.001.h5
# MAE: 0.05726763233542442
# --------------------------------------------------------
